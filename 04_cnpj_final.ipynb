# %% [markdown]
# <B>TCC PUC MINAS - MAIO/2022</B><BR>
# ANÁLISE DE PARCELAMENTO DE DÉBITOS INSCRITOS EM DÍVIDA ATIVA DA UNIÃO ATRAVÉS DE MACHINE LEARNING<BR>
# FELIPE MARTINS<BR>
#
# 04 - CNPJ FINAL: AJUSTE
#
# Tempo médio de processamento deste notebook: 50 minutos

# %%
import pandas as pd

# %%
# %%time
df_cnpj_final = pd.read_csv("03_merge_empresa_estabelecimento.csv", usecols=[1, 2, 3, 4, 5, 6, 7, 8], dtype={"CNPJ_BASICO":"category", "CNPJ_ORDEM":"category", "CNPJ_DV":"category", "SIT_CADAST":"category", "DATA_INICIO_ATIV":"category", "CNAE_PRINC":"category", "NAT_JURID":"category", "PORTE":"category"}) #nrows=5
df_cnpj_final.head()
# Out:
# Wall time: 6min 24s
#   CNPJ_BASICO CNPJ_ORDEM CNPJ_DV SIT_CADAST DATA_INICIO_ATIV CNAE_PRINC  \
# 0    44628188       0001      92          2         19730903    8512100
# 1    07349468       0001      35          2         20050329    5611204
# 2    25405580       0001      28          4         19930917    4774100
# 3    62534730       0001      20          2         19900314    4751201
# 4    80969025       0001      37          8         19881111    2399101
#
#   NAT_JURID PORTE
# 0      2062    03
# 1      2135    01
# 2      2135    01
# 3      2062    01
# 4      2135    01

# %%
df_cnpj_final.count()
# Out:
# CNPJ_BASICO         51528473
# CNPJ_ORDEM          51528473
# CNPJ_DV             51528473
# SIT_CADAST          51528473
# DATA_INICIO_ATIV    51528473
# CNAE_PRINC          51528473
# NAT_JURID           48505659
# PORTE               48446228
# dtype: int64

# %%
df_cnpj_final.isnull().sum()
# Out:
# CNPJ_BASICO               0
# CNPJ_ORDEM                0
# CNPJ_DV                   0
# SIT_CADAST                0
# DATA_INICIO_ATIV          0
# CNAE_PRINC                0
# NAT_JURID           3022814
# PORTE               3082245
# dtype: int64

# %%
df_cnpj_final.dtypes
# Out:
# CNPJ_BASICO         category
# CNPJ_ORDEM          category
# CNPJ_DV             category
# SIT_CADAST          category
# DATA_INICIO_ATIV    category
# CNAE_PRINC          category
# NAT_JURID           category
# PORTE               category
# dtype: object

# %%
df_cnpj_final.nunique()
# Out:
# CNPJ_BASICO         48828011
# CNPJ_ORDEM              9999
# CNPJ_DV                  100
# SIT_CADAST                 5
# DATA_INICIO_ATIV       23430
# CNAE_PRINC              1343
# NAT_JURID                 86
# PORTE                      3
# dtype: int64

# %%
# %%time
# AJUSTANDO CNAE_PRINC
# O número original completo possui 7 dígitos e 1343 valores distintos.
# Analisando-se a estrutura do código, observa-se que 2 dígitos já são suficientes para identificar satisfatoriamente a atividade econômica.
df_cnpj_final['CNAE_PRINC'] = df_cnpj_final['CNAE_PRINC'].str[:2]
# Out:
# Wall time: 556 ms

# %%
df_cnpj_final.head(15)
# Out:
#    CNPJ_BASICO CNPJ_ORDEM CNPJ_DV SIT_CADAST DATA_INICIO_ATIV CNAE_PRINC  \
# 0     44628188       0001      92          2         19730903         85
# 1     07349468       0001      35          2         20050329         56
# 2     25405580       0001      28          4         19930917         47
# 3     62534730       0001      20          2         19900314         47
# 4     80969025       0001      37          8         19881111         23
# 5     25409384       0001      21          3         19880831         81
# 6     80971302       0001      46          8         19881118         56
# 7     44641348       0001      33          4         19800923         47
# 8     07350395       0001      00          4         20050425         77
# 9     07350533       0001      42          4         20050429         45
# 10    80975451       0001      83          2         19881202         14
# 11    25416454       0001      79          8         19880901         47
# 12    07351008       0001      41          2         20050418         47
# 13    62548938       0001      06          2         19900323         45
# 14    07351214       0001      51          2         20050328         47
#
#    NAT_JURID PORTE
# 0       2062    03
# 1       2135    01
# 2       2135    01
# 3       2062    01
# 4       2135    01
# 5       2062    01
# 6       2135    05
# 7       2135    01
# 8       2135    01
# 9       2062    01
# 10      2062    01
# 11      2062    05
# 12      2062    01
# 13      2062    01
# 14      2062    01

# %%
# CONVERTENDO DATA PARA STRING
df_cnpj_final["DATA_INICIO_ATIV"] = df_cnpj_final["DATA_INICIO_ATIV"].astype(str)

# %%
# %%time
# CONVERTENDO CAMPO DATA_INICIO_ATIV PARA DATA
# coerce: will force the dates which are outside the bounds to 'NaT'. Há 5 registros com esse problema (devem ser datas muito antigas).

df_cnpj_final['DATA_INICIO_ATIV'] = pd.to_datetime(df_cnpj_final['DATA_INICIO_ATIV'], format="%Y/%m/%d", errors = 'coerce')
# Out:
# Wall time: 1min 28s

# %%
df_cnpj_final.head()
# Out:
#   CNPJ_BASICO CNPJ_ORDEM CNPJ_DV SIT_CADAST DATA_INICIO_ATIV CNAE_PRINC  \
# 0    44628188       0001      92          2       1973-09-03         85
# 1    07349468       0001      35          2       2005-03-29         56
# 2    25405580       0001      28          4       1993-09-17         47
# 3    62534730       0001      20          2       1990-03-14         47
# 4    80969025       0001      37          8       1988-11-11         23
#
#   NAT_JURID PORTE
# 0      2062    03
# 1      2135    01
# 2      2135    01
# 3      2062    01
# 4      2135    01

# %%
df_cnpj_final.dtypes
# Out:
# CNPJ_BASICO               category
# CNPJ_ORDEM                category
# CNPJ_DV                   category
# SIT_CADAST                category
# DATA_INICIO_ATIV    datetime64[ns]
# CNAE_PRINC                  object
# NAT_JURID                 category
# PORTE                     category
# dtype: object

# %%
# %%time
# CRIANDO NOVO CAMPO COM ANO DO INÍCIO DA ATIVIDADE
df_cnpj_final['ANO_INICIO_ATIV'] = df_cnpj_final['DATA_INICIO_ATIV'].dt.year
# Out:
# Wall time: 3.87 s

# %%
df_cnpj_final.head()
# Out:
#   CNPJ_BASICO CNPJ_ORDEM CNPJ_DV SIT_CADAST DATA_INICIO_ATIV CNAE_PRINC  \
# 0    44628188       0001      92          2       1973-09-03         85
# 1    07349468       0001      35          2       2005-03-29         56
# 2    25405580       0001      28          4       1993-09-17         47
# 3    62534730       0001      20          2       1990-03-14         47
# 4    80969025       0001      37          8       1988-11-11         23
#
#   NAT_JURID PORTE  ANO_INICIO_ATIV
# 0      2062    03           1973.0
# 1      2135    01           2005.0
# 2      2135    01           1993.0
# 3      2062    01           1990.0
# 4      2135    01           1988.0

# %%
# %%time
# CRIANDO NOVO CAMPO COM ANO ATIVIDADE MAIOR DO QUE 10 ANOS (contados do ano da base PGFN, que é 2021)
# não consegui fazer com pandas (acima). Mas deu certo com numpy:
import numpy as np
df_cnpj_final['ATIV_>10_ANOS'] = np.where(df_cnpj_final.ANO_INICIO_ATIV<=2010, 'S', 'N')
# Out:
# Wall time: 600 ms

# %%
df_cnpj_final.head()
# Out:
#   CNPJ_BASICO CNPJ_ORDEM CNPJ_DV SIT_CADAST DATA_INICIO_ATIV CNAE_PRINC  \
# 0    44628188       0001      92          2       1973-09-03         85
# 1    07349468       0001      35          2       2005-03-29         56
# 2    25405580       0001      28          4       1993-09-17         47
# 3    62534730       0001      20          2       1990-03-14         47
# 4    80969025       0001      37          8       1988-11-11         23
#
#   NAT_JURID PORTE  ANO_INICIO_ATIV ATIV_>10_ANOS
# 0      2062    03           1973.0             S
# 1      2135    01           2005.0             S
# 2      2135    01           1993.0             S
# 3      2062    01           1990.0             S
# 4      2135    01           1988.0             S

# %%
df_cnpj_final.tail()
# Out:
#          CNPJ_BASICO CNPJ_ORDEM CNPJ_DV SIT_CADAST DATA_INICIO_ATIV  \
# 51528468    62525290       0001      44          8       1990-03-19
# 51528469    62526009       0001      98          8       1969-09-25
# 51528470    07348995       0001      25          2       2005-04-29
# 51528471    80959885       0001      90          4       1988-09-29
# 51528472    25402355       0001      38          8       1988-08-25
#
#          CNAE_PRINC NAT_JURID PORTE  ANO_INICIO_ATIV ATIV_>10_ANOS
# 51528468         47      2135    05           1990.0             S
# 51528469         47      2062    01           1969.0             S
# 51528470         68      2305    03           2005.0             S
# 51528471         47      2135    01           1988.0             S
# 51528472         47      2135    05           1988.0             S

# %%
print(df_cnpj_final["ATIV_>10_ANOS"].value_counts())
# Out:
# N    29883599
# S    21644874
# Name: ATIV_>10_ANOS, dtype: int64

# %%
df_cnpj_final.dtypes
# Out:
# CNPJ_BASICO               category
# CNPJ_ORDEM                category
# CNPJ_DV                   category
# SIT_CADAST                category
# DATA_INICIO_ATIV    datetime64[ns]
# CNAE_PRINC                  object
# NAT_JURID                 category
# PORTE                     category
# ANO_INICIO_ATIV            float64
# ATIV_>10_ANOS               object
# dtype: object

# %%
# O MERGE NÃO DEU CERTO PARA 3 milhões de REGISTROS. NÃO SEI SE FOI ALGUM ERRO OU SE REALMENTE NÃO EXISTE CORRESPONDENTE.
df_cnpj_final.isnull().sum()
# Out:
# CNPJ_BASICO               0
# CNPJ_ORDEM                0
# CNPJ_DV                   0
# SIT_CADAST                0
# DATA_INICIO_ATIV          5
# CNAE_PRINC                0
# NAT_JURID           3022814
# PORTE               3082245
# ANO_INICIO_ATIV           5
# ATIV_>10_ANOS             0
# dtype: int64

# %%
# EXCLUINDO COLUNAS DESNECESSÁRIAS (para liberar memória)
df_cnpj_final = df_cnpj_final.drop(columns=['DATA_INICIO_ATIV','ANO_INICIO_ATIV'])

# %%
# %%time
# CRIANDO NOVO CAMPO CNPJ COM PONTUAÇÃO (SE DER PROBLEMA DE MEMÓRIA, FECHAR OUTROS NOTEBOOKS ABERTOS)
df_cnpj_final['CNPJ_BASICO_2'] = df_cnpj_final['CNPJ_BASICO'].str[0:2]+"."+df_cnpj_final['CNPJ_BASICO'].str[2:5]+"."+df_cnpj_final['CNPJ_BASICO'].str[5:9]
# Out:
# Wall time: 7min 29s

# %%
df_cnpj_final.head()
# Out:
#   CNPJ_BASICO CNPJ_ORDEM CNPJ_DV SIT_CADAST CNAE_PRINC NAT_JURID PORTE  \
# 0    44628188       0001      92          2         85      2062    03
# 1    07349468       0001      35          2         56      2135    01
# 2    25405580       0001      28          4         47      2135    01
# 3    62534730       0001      20          2         47      2062    01
# 4    80969025       0001      37          8         23      2135    01
#
#   ATIV_>10_ANOS CNPJ_BASICO_2
# 0             S    44.628.188
# 1             S    07.349.468
# 2             S    25.405.580
# 3             S    62.534.730
# 4             S    80.969.025

# %%
# %%time
# UNINDO AS 3 COLUNAS CNPJ
df_cnpj_final['CNPJ_BASICO_3'] = df_cnpj_final['CNPJ_BASICO_2'].str[0:]+"/"+df_cnpj_final['CNPJ_ORDEM'].str[0:]+"-"+df_cnpj_final['CNPJ_DV'].str[0:]
# Out:
# Wall time: 3min 27s

# %%
df_cnpj_final.head()
# Out:
#   CNPJ_BASICO CNPJ_ORDEM CNPJ_DV SIT_CADAST CNAE_PRINC NAT_JURID PORTE  \
# 0    44628188       0001      92          2         85      2062    03
# 1    07349468       0001      35          2         56      2135    01
# 2    25405580       0001      28          4         47      2135    01
# 3    62534730       0001      20          2         47      2062    01
# 4    80969025       0001      37          8         23      2135    01
#
#   ATIV_>10_ANOS CNPJ_BASICO_2       CNPJ_BASICO_3
# 0             S    44.628.188  44.628.188/0001-92
# 1             S    07.349.468  07.349.468/0001-35
# 2             S    25.405.580  25.405.580/0001-28
# 3             S    62.534.730  62.534.730/0001-20
# 4             S    80.969.025  80.969.025/0001-37

# %%
# EXCLUINDO COLUNAS DESNECESSÁRIAS
df_cnpj_final = df_cnpj_final.drop(columns=['CNPJ_BASICO','CNPJ_ORDEM','CNPJ_DV','CNPJ_BASICO_2'])

# %%
df_cnpj_final.head()
# Out:
#   SIT_CADAST CNAE_PRINC NAT_JURID PORTE ATIV_>10_ANOS       CNPJ_BASICO_3
# 0          2         85      2062    03             S  44.628.188/0001-92
# 1          2         56      2135    01             S  07.349.468/0001-35
# 2          4         47      2135    01             S  25.405.580/0001-28
# 3          2         47      2062    01             S  62.534.730/0001-20
# 4          8         23      2135    01             S  80.969.025/0001-37

# %%
#REORDENANDO COLUNAS
df_cnpj_final = df_cnpj_final[['CNPJ_BASICO_3','SIT_CADAST','CNAE_PRINC','NAT_JURID','PORTE','ATIV_>10_ANOS']]

# %%
df_cnpj_final.head()
# Out:
#         CNPJ_BASICO_3 SIT_CADAST CNAE_PRINC NAT_JURID PORTE ATIV_>10_ANOS
# 0  44.628.188/0001-92          2         85      2062    03             S
# 1  07.349.468/0001-35          2         56      2135    01             S
# 2  25.405.580/0001-28          4         47      2135    01             S
# 3  62.534.730/0001-20          2         47      2062    01             S
# 4  80.969.025/0001-37          8         23      2135    01             S

# %%
# %%time
# RENOMEANDO COLUNA
df_cnpj_final = df_cnpj_final.rename(columns = {'CNPJ_BASICO_3': 'CNPJ_BASICO'})
# Out:
# Wall time: 22.1 s

# %%
# %%time
# EXPORTANTO DATASET FINAL
df_cnpj_final.to_csv("04_cnpj_final.csv")
# Out:
# Wall time: 2min 16s

# %%
df_cnpj_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51528473 entries, 0 to 51528472
# Data columns (total 6 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   CNPJ_BASICO    object
#  1   SIT_CADAST     category
#  2   CNAE_PRINC     object
#  3   NAT_JURID      category
#  4   PORTE          category
#  5   ATIV_>10_ANOS  object
# dtypes: category(3), object(3)
# memory usage: 1.3+ GB
