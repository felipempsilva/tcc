# %% [markdown]
# <B>TCC PUC MINAS - MAIO/2022</B><BR>
# ANÁLISE DE PARCELAMENTO DE DÉBITOS INSCRITOS EM DÍVIDA ATIVA DA UNIÃO ATRAVÉS DE MACHINE LEARNING<BR>
# FELIPE MARTINS<BR>
#
# 07 - CONVERTENDO TIPO DE DADOS PARA DADOS QUANTITATIVOS
#
# Tempo aproximado de processamento: 5 minutos

# %% [markdown]
# # 1. Prepraro inicial

# %%
import pandas as pd
from sklearn.model_selection import StratifiedShuffleSplit

# %%
# %%time
# IMPORTANDO O DATASET
df = pd.read_csv("06_dataset_final_com_dados_categoricos.csv")
# Out:
# Wall time: 24.9 s

# %%
df = df.drop(columns=['Unnamed: 0'])

# %%
df.head()
# Out:
#   TIPO_PESSOA TIPO_SITUACAO_INSCRICAO  \
# 0          PJ             Em cobrança
# 1          PJ             Em cobrança
# 2          PF        Benefício Fiscal
# 3          PJ             Em cobrança
# 4          PJ             Em cobrança
#
#                         SITUACAO_INSCRICAO RECEITA_PRINCIPAL  \
# 0                        ATIVA EM COBRANCA  SIMPLES NACIONAL
# 1                           ATIVA AJUIZADA       Multa - CLT
# 2  ATIVA NAO AJUIZAVEL NEGOCIADA NO SISPAR            OUTROS
# 3                           ATIVA AJUIZADA            COFINS
# 4                        ATIVA EM COBRANCA     Multa Isolada
#
#   INDICADOR_AJUIZADO HA_OUTROS_DEBITOS INSC_>1_ANO  VALOR_CONSOLIDADO  \
# 0                NAO                 S           S           55464.40
# 1                SIM                 S           S           55446.40
# 2                NAO                 S           N            3182.70
# 3                SIM                 S           S         3457828.22
# 4                NAO                 N           S            1521.30
#
#    VALOR_FAIXA  SIT_CADAST  CNAE_PRINC  NAT_JURID  PORTE ATIV_>10_ANOS  \
# 0          6.0         4.0        47.0     2062.0    3.0             S
# 1          6.0         4.0        46.0     2062.0    5.0             S
# 2          2.0         NaN         NaN        NaN    NaN           NaN
# 3          9.0         8.0        26.0     2054.0    5.0             S
# 4          2.0         4.0        41.0     2062.0    1.0             S
#
#   PARCELADO
# 0         N
# 1         N
# 2         S
# 3         N
# 4         N

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14992922 entries, 0 to 14992921
# Data columns (total 15 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   TIPO_PESSOA              object
#  1   TIPO_SITUACAO_INSCRICAO  object
#  2   SITUACAO_INSCRICAO       object
#  3   RECEITA_PRINCIPAL        object
#  4   INDICADOR_AJUIZADO       object
#  5   HA_OUTROS_DEBITOS        object
#  6   INSC_>1_ANO              object
#  7   VALOR_CONSOLIDADO        float64
#  8   VALOR_FAIXA              float64
#  9   SIT_CADAST               float64
#  10  CNAE_PRINC               float64
#  11  NAT_JURID                float64
#  12  PORTE                    float64
#  13  ATIV_>10_ANOS            object
#  14  PARCELADO                object
# dtypes: float64(6), object(9)
# memory usage: 1.7+ GB

# %% [markdown]
# ### Reduzindo a quantidade de linhas do dataset (redução de numerosidade / amostragem estratificada)

# %%
# Contando a quantidade de classes no dataset original
df['PARCELADO'].value_counts()
# Out:
# N    11540162
# S     3452760
# Name: PARCELADO, dtype: int64

# %%
3452760 / len(df)  # proporção da classe minoritária. Após o split conferir se será mantida.
# Out:
# 0.23029266743333954

# %%
# %%time
# Dividindo o dataset
split = StratifiedShuffleSplit(test_size=0.05)
for x, y in split.split(df, df['PARCELADO']):
    df1 = df.iloc[x]  # 95% dos dados
    df2 = df.iloc[y]  # 5% dos dados. Utilizar essa.
# Out:
# Wall time: 4min 15s

# %%
# Resultado da divisão
print("dataset original: ",df.shape)
print("dataset 95%: ",df1.shape)
print("dataset 5% - nossa amostra: ",df2.shape)
# Out:
# dataset original:  (14992922, 15)
# dataset 95%:  (14243275, 15)
# dataset 5% - nossa amostra:  (749647, 15)

# %%
# Contando a quantidade de classes no dataset reduzido
df2['PARCELADO'].value_counts()
# Out:
# N    577009
# S    172638
# Name: PARCELADO, dtype: int64

# %%
172638 / len(df2)  # confirmação de que proporção da classe minoritária foi mantida.
# Out:
# 0.23029239095200807

# %%
df2
# Out:
#          TIPO_PESSOA TIPO_SITUACAO_INSCRICAO  \
# 1419707           PJ             Em cobrança
# 7240218           PJ        Benefício Fiscal
# 8072359           PJ             Em cobrança
# 6579675           PJ        Benefício Fiscal
# 12352983          PJ        Benefício Fiscal
# ...              ...                     ...
# 9569274           PJ             Em cobrança
# 3118302           PJ             Em cobrança
# 4351186           PJ             Em cobrança
# 14139953          PJ             Em cobrança
# 10318597          PF             Em cobrança
#
#                                SITUACAO_INSCRICAO RECEITA_PRINCIPAL  \
# 1419707                         ATIVA EM COBRANCA              IRPJ
# 7240218   ATIVA NAO AJUIZAVEL NEGOCIADA NO SISPAR            COFINS
# 8072359                            ATIVA AJUIZADA            COFINS
# 6579675   ATIVA NAO AJUIZAVEL NEGOCIADA NO SISPAR              IRPJ
# 12352983  ATIVA NAO AJUIZAVEL NEGOCIADA NO SISPAR              CSLL
# ...                                           ...               ...
# 9569274                         ATIVA EM COBRANCA              IRPJ
# 3118302                      ATIVA A SER AJUIZADA              IRPJ
# 4351186                         ATIVA EM COBRANCA     Multa Isolada
# 14139953                        ATIVA EM COBRANCA            COFINS
# 10318597                        ATIVA EM COBRANCA              IRPF
#
#          INDICADOR_AJUIZADO HA_OUTROS_DEBITOS INSC_>1_ANO  VALOR_CONSOLIDADO  \
# 1419707                 NAO                 S           S          982303.77
# 7240218                 NAO                 S           S            1310.36
# 8072359                 SIM                 S           S          250254.82
# 6579675                 NAO                 S           N            2362.03
# 12352983                NAO                 S           S            2654.63
# ...                     ...               ...         ...                ...
# 9569274                 NAO                 S           S            4773.30
# 3118302                 NAO                 S           S            4495.06
# 4351186                 NAO                 N           S            1374.01
# 14139953                NAO                 S           N           99483.59
# 10318597                NAO                 S           N            6567.89
#
#           VALOR_FAIXA  SIT_CADAST  CNAE_PRINC  NAT_JURID  PORTE ATIV_>10_ANOS  \
# 1419707           8.0         4.0        71.0     2062.0    1.0             S
# 7240218           2.0         2.0        86.0     2135.0    1.0             S
# 8072359           7.0         4.0        85.0     2240.0    5.0             S
# 6579675           2.0         2.0        41.0     2305.0    3.0             N
# 12352983          2.0         2.0        70.0     2062.0    1.0             S
# ...               ...         ...         ...        ...    ...           ...
# 9569274           2.0         2.0        56.0     2062.0    1.0             N
# 3118302           2.0         2.0        47.0     2135.0    1.0             S
# 4351186           2.0         2.0        68.0     2054.0    5.0             S
# 14139953          6.0         2.0        28.0     2062.0    5.0             S
# 10318597          3.0         NaN         NaN        NaN    NaN           NaN
#
#          PARCELADO
# 1419707          N
# 7240218          S
# 8072359          N
# 6579675          S
# 12352983         S
# ...            ...
# 9569274          N
# 3118302          N
# 4351186          N
# 14139953         N
# 10318597         N
#
# [749647 rows x 15 columns]

# %% [markdown]
# ### Verificação do dataset reduzido

# %%
# CHECANDO SE HÁ DADOS NULOS / NAN (NOT A NUMBER)
# RESULTADO: COLUNAS VINDAS DA BASE CNPJ POSSUEM MAIS DE 2 MILHÕES DE DADOS NULOS. SE REFEREM AOS DEBITOS DE PESSOA FÍSICA, QUE, OBVIAMENTE, NÃO TÊM REGISTRO NA BASE CNPJ.
df2.isna().sum()
# Out:
# TIPO_PESSOA                     0
# TIPO_SITUACAO_INSCRICAO         0
# SITUACAO_INSCRICAO              0
# RECEITA_PRINCIPAL               0
# INDICADOR_AJUIZADO              0
# HA_OUTROS_DEBITOS               0
# INSC_>1_ANO                     0
# VALOR_CONSOLIDADO               0
# VALOR_FAIXA                     0
# SIT_CADAST                 138293
# CNAE_PRINC                 138293
# NAT_JURID                  138305
# PORTE                      138305
# ATIV_>10_ANOS              138293
# PARCELADO                       0
# dtype: int64

# %%
df2['TIPO_PESSOA'].value_counts()  #contador de frequência
# Out:
# PJ    611442
# PF    138205
# Name: TIPO_PESSOA, dtype: int64

# %%
# SUBSTITUINDO DADOS NULOS / NAN POR ZERO PARA EVITAR ERROS NAS CONVERSÕES
df2.fillna(value = 0, inplace = True)
df2.isna().sum()
# Out:
# C:\Users\62914855320\Anaconda3\lib\site-packages\pandas\core\frame.py:5176: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(
# TIPO_PESSOA                0
# TIPO_SITUACAO_INSCRICAO    0
# SITUACAO_INSCRICAO         0
# RECEITA_PRINCIPAL          0
# INDICADOR_AJUIZADO         0
# HA_OUTROS_DEBITOS          0
# INSC_>1_ANO                0
# VALOR_CONSOLIDADO          0
# VALOR_FAIXA                0
# SIT_CADAST                 0
# CNAE_PRINC                 0
# NAT_JURID                  0
# PORTE                      0
# ATIV_>10_ANOS              0
# PARCELADO                  0
# dtype: int64

# %%
# ENUMERA A QDE DE VARIAÇÕES DE CADA COLUNA
df2.nunique()
# Out:
# TIPO_PESSOA                     2
# TIPO_SITUACAO_INSCRICAO         5
# SITUACAO_INSCRICAO             83
# RECEITA_PRINCIPAL              13
# INDICADOR_AJUIZADO              2
# HA_OUTROS_DEBITOS               2
# INSC_>1_ANO                     2
# VALOR_CONSOLIDADO          609542
# VALOR_FAIXA                    10
# SIT_CADAST                      6
# CNAE_PRINC                     81
# NAT_JURID                      59
# PORTE                           4
# ATIV_>10_ANOS                   3
# PARCELADO                       2
# dtype: int64

# %%
df2.dtypes
# Out:
# TIPO_PESSOA                 object
# TIPO_SITUACAO_INSCRICAO     object
# SITUACAO_INSCRICAO          object
# RECEITA_PRINCIPAL           object
# INDICADOR_AJUIZADO          object
# HA_OUTROS_DEBITOS           object
# INSC_>1_ANO                 object
# VALOR_CONSOLIDADO          float64
# VALOR_FAIXA                float64
# SIT_CADAST                 float64
# CNAE_PRINC                 float64
# NAT_JURID                  float64
# PORTE                      float64
# ATIV_>10_ANOS               object
# PARCELADO                   object
# dtype: object

# %% [markdown]
# ## PARTE 2 - NORMALIZANDO VARIÁVEIS CONTÍNUAS
# MÉTODO: MinMaxScaler

# %%
# %%time
from sklearn.preprocessing import MinMaxScaler
variaveis_continuas = ['VALOR_FAIXA', 'VALOR_CONSOLIDADO']
scaler = MinMaxScaler()
df2[variaveis_continuas] = scaler.fit_transform(df2[variaveis_continuas])
df2[variaveis_continuas]
# Out:
# Wall time: 156 ms
# C:\Users\62914855320\Anaconda3\lib\site-packages\pandas\core\frame.py:3678: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[col] = igetitem(value, i)
#           VALOR_FAIXA  VALOR_CONSOLIDADO
# 1419707      0.777778       1.024026e-04
# 7240218      0.111111       1.364299e-07
# 8072359      0.666667       2.608829e-05
# 6579675      0.111111       2.460639e-07
# 12352983     0.111111       2.765668e-07
# ...               ...                ...
# 9569274      0.111111       4.974330e-07
# 3118302      0.111111       4.684272e-07
# 4351186      0.111111       1.430652e-07
# 14139953     0.555556       1.037075e-05
# 10318597     0.222222       6.845147e-07
#
# [749647 rows x 2 columns]

# %% [markdown]
# ## PARTE 3 - CONVERTENDO VARIÁVEIS CATEGÓRICAS BINÁRIAS
# MÉTODO: REPLACE

# %%
# %%time
df2['TIPO_PESSOA'] = df2['TIPO_PESSOA'].replace(['PJ','PF'],['1','0'])
df2['INDICADOR_AJUIZADO'] = df2['INDICADOR_AJUIZADO'].replace(['SIM','NAO'],['1','0'])
df2['HA_OUTROS_DEBITOS'] = df2['HA_OUTROS_DEBITOS'].replace(['S','N'],['1','0'])
df2['INSC_>1_ANO'] = df2['INSC_>1_ANO'].replace(['S','N'],['1','0'])
df2['ATIV_>10_ANOS'] = df2['ATIV_>10_ANOS'].replace(['S','N'],['1','0'])
df2['PARCELADO'] = df2['PARCELADO'].replace(['S','N'],['1','0'])
df2.head()
# Out:
# <timed exec>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Wall time: 566 ms
# <timed exec>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#          TIPO_PESSOA TIPO_SITUACAO_INSCRICAO  \
# 1419707            1             Em cobrança
# 7240218            1        Benefício Fiscal
# 8072359            1             Em cobrança
# 6579675            1        Benefício Fiscal
# 12352983           1        Benefício Fiscal
#
#                                SITUACAO_INSCRICAO RECEITA_PRINCIPAL  \
# 1419707                         ATIVA EM COBRANCA              IRPJ
# 7240218   ATIVA NAO AJUIZAVEL NEGOCIADA NO SISPAR            COFINS
# 8072359                            ATIVA AJUIZADA            COFINS
# 6579675   ATIVA NAO AJUIZAVEL NEGOCIADA NO SISPAR              IRPJ
# 12352983  ATIVA NAO AJUIZAVEL NEGOCIADA NO SISPAR              CSLL
#
#          INDICADOR_AJUIZADO HA_OUTROS_DEBITOS INSC_>1_ANO  VALOR_CONSOLIDADO  \
# 1419707                   0                 1           1       1.024026e-04
# 7240218                   0                 1           1       1.364299e-07
# 8072359                   1                 1           1       2.608829e-05
# 6579675                   0                 1           0       2.460639e-07
# 12352983                  0                 1           1       2.765668e-07
#
#           VALOR_FAIXA  SIT_CADAST  CNAE_PRINC  NAT_JURID  PORTE ATIV_>10_ANOS  \
# 1419707      0.777778         4.0        71.0     2062.0    1.0             1
# 7240218      0.111111         2.0        86.0     2135.0    1.0             1
# 8072359      0.666667         4.0        85.0     2240.0    5.0             1
# 6579675      0.111111         2.0        41.0     2305.0    3.0             0
# 12352983     0.111111         2.0        70.0     2062.0    1.0             1
#
#          PARCELADO
# 1419707          0
# 7240218          1
# 8072359          0
# 6579675          1
# 12352983         1

# %%
# %%time
# CONVERTENDO TIPO DE DADOS PARA INTEIRO
df2["TIPO_PESSOA"] = df2["TIPO_PESSOA"].astype("int64")
df2["INDICADOR_AJUIZADO"] = df2["INDICADOR_AJUIZADO"].astype("int64")
df2["HA_OUTROS_DEBITOS"] = df2["HA_OUTROS_DEBITOS"].astype("int64")
df2["INSC_>1_ANO"] = df2["INSC_>1_ANO"].astype("int64")
df2["ATIV_>10_ANOS"] = df2["ATIV_>10_ANOS"].astype("int64")
df2["PARCELADO"] = df2["PARCELADO"].astype("int64")
# Out:
# <timed exec>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <timed exec>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Wall time: 478 ms
# <timed exec>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 749647 entries, 1419707 to 10318597
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   TIPO_PESSOA              749647 non-null  int64
#  1   TIPO_SITUACAO_INSCRICAO  749647 non-null  object
#  2   SITUACAO_INSCRICAO       749647 non-null  object
#  3   RECEITA_PRINCIPAL        749647 non-null  object
#  4   INDICADOR_AJUIZADO       749647 non-null  int64
#  5   HA_OUTROS_DEBITOS        749647 non-null  int64
#  6   INSC_>1_ANO              749647 non-null  int64
#  7   VALOR_CONSOLIDADO        749647 non-null  float64
#  8   VALOR_FAIXA              749647 non-null  float64
#  9   SIT_CADAST               749647 non-null  float64
#  10  CNAE_PRINC               749647 non-null  float64
#  11  NAT_JURID                749647 non-null  float64
#  12  PORTE                    749647 non-null  float64
#  13  ATIV_>10_ANOS            749647 non-null  int64
#  14  PARCELADO                749647 non-null  int64
# dtypes: float64(6), int64(6), object(3)
# memory usage: 91.5+ MB

# %% [markdown]
# ## PARTE 4 - CONVERTENDO  VARIÁVEIS CATEGÓRICAS MULTICLASSE
# UTILIZAÇÃO DE ENCODER WOEEncoder

# %%
# CONVERTENDO A CATEGORIA-ALVO (PARCELADO) PARA INTEIRO, POIS É NECESSÁRIO PARA OS ENCODERS A SEGUIR
df2["PARCELADO"] = df2["PARCELADO"].astype("int64")
# Out:
# C:\Users\629148~1\AppData\Local\Temp/ipykernel_10172/1191843944.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["PARCELADO"] = df2["PARCELADO"].astype("int64")

# %%
pip install category_encoders
# Out:
# Requirement already satisfied: category_encoders in c:\users\62914855320\anaconda3\lib\site-packages (2.4.0)Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas>=0.21.1 in c:\users\62914855320\anaconda3\lib\site-packages (from category_encoders) (1.3.4)
# Requirement already satisfied: patsy>=0.5.1 in c:\users\62914855320\anaconda3\lib\site-packages (from category_encoders) (0.5.2)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\users\62914855320\anaconda3\lib\site-packages (from category_encoders) (1.0.2)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\62914855320\anaconda3\lib\site-packages (from category_encoders) (1.20.3)
# Requirement already satisfied: statsmodels>=0.9.0 in c:\users\62914855320\anaconda3\lib\site-packages (from category_encoders) (0.12.2)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\62914855320\anaconda3\lib\site-packages (from category_encoders) (1.7.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\62914855320\anaconda3\lib\site-packages (from pandas>=0.21.1->category_encoders) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\62914855320\anaconda3\lib\site-packages (from pandas>=0.21.1->category_encoders) (2021.3)
# Requirement already satisfied: six in c:\users\62914855320\anaconda3\lib\site-packages (from patsy>=0.5.1->category_encoders) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\62914855320\anaconda3\lib\site-packages (from scikit-learn>=0.20.0->category_encoders) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\62914855320\anaconda3\lib\site-packages (from scikit-learn>=0.20.0->category_encoders) (1.1.0)

# %%
# %%time
from category_encoders import WOEEncoder

y = df2['PARCELADO']
X = df2['TIPO_SITUACAO_INSCRICAO']
encoder = WOEEncoder(cols=['TIPO_SITUACAO_INSCRICAO']).fit(X, y)
df2['COD_TIPO_SIT_INSC'] = encoder.transform(X)
df2[['TIPO_SITUACAO_INSCRICAO', 'COD_TIPO_SIT_INSC']].groupby('TIPO_SITUACAO_INSCRICAO').agg(lambda x: list(set(x))).reset_index()
# Out:
# Wall time: 1.64 s
# <timed exec>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#          TIPO_SITUACAO_INSCRICAO      COD_TIPO_SIT_INSC
# 0               Benefício Fiscal   [13.265610817016155]
# 1                    Em cobrança  [-12.053439120593527]
# 2                  Em negociação  [-3.3366419533286638]
# 3                       Garantia  [-6.3643057542276695]
# 4  Suspenso por decisão judicial   [-5.837380068333345]

# %%
# %%time
from category_encoders import WOEEncoder

y = df2['PARCELADO']
X = df2['SITUACAO_INSCRICAO']
encoder = WOEEncoder(cols=['SITUACAO_INSCRICAO']).fit(X, y)
df2['COD_SIT_INSC'] = encoder.transform(X)
df2[['SITUACAO_INSCRICAO', 'COD_SIT_INSC']].groupby('SITUACAO_INSCRICAO').agg(lambda x: list(set(x))).reset_index()
# Out:
# <timed exec>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Wall time: 1.3 s
#                                    SITUACAO_INSCRICAO            COD_SIT_INSC
# 0                                ATIVA A SER AJUIZADA    [-9.848750784285208]
# 1                                 ATIVA A SER COBRADA    [-7.891190511807697]
# 2                                      ATIVA AJUIZADA   [-10.923434699084284]
# 3   ATIVA AJUIZADA - ART. 910 CPC - CONTENCIOSO FA...  [-0.17964153217855033]
# 4            ATIVA AJUIZADA - GARANTIA - CARTA FIANCA   [-3.8809435062910436]
# ..                                                ...                     ...
# 78            ATIVA NAO AJUIZAVEL NEGOCIADA NO SISPAR    [12.997050926944457]
# 79  ATIVA NAO AJUIZAVEL NEGOCIADA NO SISPAR - BLOQ...      [5.01331531871166]
# 80              ATIVA NAO PRIORIZADA PARA AJUIZAMENTO    [-9.434094478773053]
# 81  ATIVA PARCELADA TIMEMANIA-DEM ENT COM AJUIZAME...                   [0.0]
# 82        ATIVA PREPARADA PARA AJUIZAMENTO ELETRONICO    [-6.378120248670858]
#
# [83 rows x 2 columns]

# %%
# %%time
y = df2['PARCELADO']
X = df2['RECEITA_PRINCIPAL']
encoder = WOEEncoder(cols=['RECEITA_PRINCIPAL']).fit(X, y)
df2['COD_RECEITA'] = encoder.transform(X)
df2[['RECEITA_PRINCIPAL', 'COD_RECEITA']].groupby('RECEITA_PRINCIPAL').agg(lambda x: list(set(x))).reset_index()
# Out:
# Wall time: 1.21 s
# <timed exec>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#    RECEITA_PRINCIPAL             COD_RECEITA
# 0             COFINS  [-0.06619694423417793]
# 1               CSLL   [0.02123659380639308]
# 2               IRPF   [0.18373029321957066]
# 3               IRPJ  [0.009147319274119804]
# 4               IRRF  [-0.11991071260908229]
# 5        Multa - CLT   [-0.4788973990601102]
# 6      Multa Isolada   [-0.6291436494817317]
# 7             OUTROS  [-0.21704902569012627]
# 8                PIS  [-0.14337822204361933]
# 9     SIMP NAC - MEI   [-1.1612239913070337]
# 10           SIMPLES  [-0.47567620570570013]
# 11  SIMPLES NACIONAL    [0.5814392712681504]
# 12               SPU   [-1.4444330765395255]

# %%
# %%time
y = df2['PARCELADO']
X = df2['SIT_CADAST']
encoder = WOEEncoder(cols=['SIT_CADAST']).fit(X, y)
df2['COD_SIT_CADAST'] = encoder.transform(X)
df2[['SIT_CADAST', 'COD_SIT_CADAST']].groupby('SIT_CADAST').agg(lambda x: list(set(x))).reset_index()
# Out:
# Wall time: 917 ms
# <timed exec>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#    SIT_CADAST         COD_SIT_CADAST
# 0         0.0  [-0.1108332483556772]
# 1         1.0  [-1.4674958204851885]
# 2         2.0  [0.49052188938081365]
# 3         3.0  [-0.7955398604045252]
# 4         4.0  [-1.5564705135811534]
# 5         8.0  [-1.0092636476935595]

# %%
# %%time
y = df2['PARCELADO']
X = df2['CNAE_PRINC']
encoder = WOEEncoder(cols=['CNAE_PRINC']).fit(X, y)
df2['COD_CNAE_PRINC'] = encoder.transform(X)
df2[['CNAE_PRINC', 'COD_CNAE_PRINC']].groupby('CNAE_PRINC').agg(lambda x: list(set(x))).reset_index()
# Out:
# Wall time: 909 ms
# <timed exec>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#     CNAE_PRINC          COD_CNAE_PRINC
# 0          0.0   [-0.1108332483556772]
# 1         10.0  [-0.02581632021421384]
# 2         11.0   [0.31558315114496055]
# 3         12.0  [-0.34148455762896424]
# 4         13.0   [-0.0506546629713501]
# ..         ...                     ...
# 76        94.0   [-0.7981363253639957]
# 77        95.0  [-0.18480248346816777]
# 78        96.0  [-0.25251532565854823]
# 79        97.0    [-1.471319916923592]
# 80        99.0    [-0.074281016520724]
#
# [81 rows x 2 columns]

# %%
df2['COD_CNAE_PRINC'].value_counts()  #contador de frequência
# Out:
# -0.110833    138293
#  0.000292    124003
#  0.052058     59810
#  0.013222     32584
# -0.059852     27516
#               ...
# -1.471320       138
# -0.467324       131
# -1.332321        80
# -0.074281        67
#  0.660109        28
# Name: COD_CNAE_PRINC, Length: 81, dtype: int64

# %%
# %%time
y = df2['PARCELADO']
X = df2['NAT_JURID']
encoder = WOEEncoder(cols=['NAT_JURID']).fit(X, y)
df2['COD_NAT_JURID'] = encoder.transform(X)
df2[['NAT_JURID', 'COD_NAT_JURID']].groupby('NAT_JURID').agg(lambda x: list(set(x))).reset_index()
# Out:
# Wall time: 914 ms
# <timed exec>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#     NAT_JURID           COD_NAT_JURID
# 0         0.0  [-0.11089985409075033]
# 1      1015.0                   [0.0]
# 2      1023.0      [1.20665282894134]
# 3      1031.0    [-0.690467155944541]
# 4      1066.0   [0.01706876206750396]
# 5      1082.0                   [0.0]
# 6      1104.0   [-0.9905717483948789]
# 7      1112.0   [0.10804054027323066]
# 8      1120.0    [0.0874212530704949]
# 9      1147.0   [0.29036209706718524]
# 10     1155.0   [0.20812399883021318]
# 11     1163.0                   [0.0]
# 12     1180.0    [1.2066528289413403]
# 13     1210.0     [0.754667705198283]
# 14     1236.0    [1.2066528289413403]
# 15     1244.0    [0.9173273707458294]
# 16     1260.0                   [0.0]
# 17     1279.0    [0.5135056483813949]
# 18     1333.0  [-0.04611013955402774]
# 19     2011.0   [0.42455816236489885]
# 20     2038.0    [0.4015877321774096]
# 21     2046.0   [-0.9272768980225654]
# 22     2054.0  [-0.02339471244547353]
# 23     2062.0  [0.023339809566626436]
# 24     2070.0   [-0.7833821250229109]
# 25     2089.0     [0.513505648381395]
# 26     2097.0   [0.10804054027323066]
# 27     2100.0   [-0.5851066402867149]
# 28     2127.0    [0.9835092776271306]
# 29     2135.0  [-0.06057310816582752]
# 30     2143.0  [-0.24438562429022415]
# 31     2151.0  [0.005625534845161068]
# 32     2160.0     [0.513505648381395]
# 33     2178.0   [-2.8006803562911307]
# 34     2216.0    [-0.498095263297085]
# 35     2232.0    [0.8056420711825563]
# 36     2240.0    [0.1159576410048922]
# 37     2259.0   [0.39572261272501164]
# 38     2267.0                   [0.0]
# 39     2283.0   [-0.5851066402867149]
# 40     2305.0   [0.14742862099731238]
# 41     2313.0    [0.2599670198952942]
# 42     2321.0    [0.5362856767132148]
# 43     2330.0   [0.10804054027323046]
# 44     3034.0   [-0.4027850834927601]
# 45     3069.0  [0.022882731932923724]
# 46     3077.0   [-0.4027850834927601]
# 47     3085.0  [-0.41520760349131725]
# 48     3115.0   [-0.4027850834927601]
# 49     3131.0   [0.14578086825607767]
# 50     3220.0    [-0.711669363595144]
# 51     3263.0    [-0.033038057986675]
# 52     3271.0   [-2.9013238820708183]
# 53     3301.0   [-0.4027850834927601]
# 54     3999.0   [-0.1746490105754293]
# 55     4014.0  [-0.25166012458203885]
# 56     4120.0   [-1.7111179031429389]
# 57     5029.0   [0.10804054027323046]
# 58     8885.0   [0.10804054027323046]

# %%
df2['COD_NAT_JURID'].value_counts()  #contador de frequência
# Out:
#  0.023340    342291
# -0.110900    138305
# -0.060573    135622
#  0.147429     82932
#  0.115958     21176
# -0.023395     13019
# -0.174649      4998
#  0.805642      2429
#  0.259967      1783
# -0.244386      1199
# -0.927277      1179
# -2.901324      1049
#  0.536286       654
# -0.251660       406
#  0.917327       353
#  0.145781       348
# -0.711669       326
#  0.022883       254
#  0.401588       244
# -0.415208       192
# -0.783382       156
#  0.005626       145
#  0.424558       135
#  0.087421        63
# -2.800680        54
# -0.033038        47
# -1.711118        37
#  0.017069        28
#  0.108041        28
# -0.402785        28
#  0.208124        24
# -0.690467        21
#  0.754668        16
# -0.046110        16
#  0.395723        11
# -0.498095        11
# -0.585107        10
#  0.513506         8
# -0.990572         8
#  1.206653         8
#  0.983509         7
#  0.513506         7
#  0.108041         6
#  0.290362         5
#  0.000000         5
#  1.206653         4
# Name: COD_NAT_JURID, dtype: int64

# %%
# %%time
y = df2['PARCELADO']
X = df2['PORTE']
encoder = WOEEncoder(cols=['PORTE']).fit(X, y)
df2['COD_PORTE'] = encoder.transform(X)
df2[['PORTE', 'COD_PORTE']].groupby('PORTE').agg(lambda x: list(set(x))).reset_index()
# Out:
# Wall time: 963 ms
# <timed exec>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#    PORTE               COD_PORTE
# 0    0.0  [-0.11089985409075033]
# 1    1.0   [0.04148408148794645]
# 2    3.0   [0.12510534065668957]
# 3    5.0  [-0.08052361027016987]

# %%
df2['COD_PORTE'].value_counts()  #contador de frequência
# Out:
#  0.041484    343990
# -0.080524    163955
# -0.110900    138305
#  0.125105    103397
# Name: COD_PORTE, dtype: int64

# %% [markdown]
# ## PARTE 5 - PROCEDIMENTOS FINAIS

# %%
df2.head()
# Out:
#           TIPO_PESSOA TIPO_SITUACAO_INSCRICAO  \
# 1419707             1             Em cobrança
# 7240218             1        Benefício Fiscal
# 8072359             1             Em cobrança
# 6579675             1        Benefício Fiscal
# 12352983            1        Benefício Fiscal
#
#                                SITUACAO_INSCRICAO RECEITA_PRINCIPAL  \
# 1419707                         ATIVA EM COBRANCA              IRPJ
# 7240218   ATIVA NAO AJUIZAVEL NEGOCIADA NO SISPAR            COFINS
# 8072359                            ATIVA AJUIZADA            COFINS
# 6579675   ATIVA NAO AJUIZAVEL NEGOCIADA NO SISPAR              IRPJ
# 12352983  ATIVA NAO AJUIZAVEL NEGOCIADA NO SISPAR              CSLL
#
#           INDICADOR_AJUIZADO  HA_OUTROS_DEBITOS  INSC_>1_ANO  \
# 1419707                    0                  1            1
# 7240218                    0                  1            1
# 8072359                    1                  1            1
# 6579675                    0                  1            0
# 12352983                   0                  1            1
#
#           VALOR_CONSOLIDADO  VALOR_FAIXA  SIT_CADAST  ...  PORTE  \
# 1419707        1.024026e-04     0.777778         4.0  ...    1.0
# 7240218        1.364299e-07     0.111111         2.0  ...    1.0
# 8072359        2.608829e-05     0.666667         4.0  ...    5.0
# 6579675        2.460639e-07     0.111111         2.0  ...    3.0
# 12352983       2.765668e-07     0.111111         2.0  ...    1.0
#
#           ATIV_>10_ANOS  PARCELADO  COD_TIPO_SIT_INSC  COD_SIT_INSC  \
# 1419707               1          0         -12.053439    -11.230282
# 7240218               1          1          13.265611     12.997051
# 8072359               1          0         -12.053439    -10.923435
# 6579675               0          1          13.265611     12.997051
# 12352983              1          1          13.265611     12.997051
#
#           COD_RECEITA  COD_SIT_CADAST  COD_CNAE_PRINC  COD_NAT_JURID  \
# 1419707      0.009147       -1.556471        0.275200       0.023340
# 7240218     -0.066197        0.490522        0.586070      -0.060573
# 8072359     -0.066197       -1.556471        0.198774       0.115958
# 6579675      0.009147        0.490522       -0.059852       0.147429
# 12352983     0.021237        0.490522        0.295323       0.023340
#
#           COD_PORTE
# 1419707    0.041484
# 7240218    0.041484
# 8072359   -0.080524
# 6579675    0.125105
# 12352983   0.041484
#
# [5 rows x 22 columns]

# %%
# EXCLUINDO COLUNAS REDUNDANTES
df2 = df2.drop(columns=['TIPO_SITUACAO_INSCRICAO','SITUACAO_INSCRICAO','RECEITA_PRINCIPAL','SIT_CADAST','CNAE_PRINC','NAT_JURID','PORTE'])

# %%
# REORDENANDO COLUNAS
df2 = df2[['TIPO_PESSOA','COD_TIPO_SIT_INSC','COD_SIT_INSC','COD_RECEITA','INDICADOR_AJUIZADO','HA_OUTROS_DEBITOS','INSC_>1_ANO','VALOR_CONSOLIDADO','VALOR_FAIXA','COD_SIT_CADAST','COD_CNAE_PRINC','COD_NAT_JURID','COD_PORTE','ATIV_>10_ANOS','PARCELADO']]
df2.head()
# Out:
#           TIPO_PESSOA  COD_TIPO_SIT_INSC  COD_SIT_INSC  COD_RECEITA  \
# 1419707             1         -12.053439    -11.230282     0.009147
# 7240218             1          13.265611     12.997051    -0.066197
# 8072359             1         -12.053439    -10.923435    -0.066197
# 6579675             1          13.265611     12.997051     0.009147
# 12352983            1          13.265611     12.997051     0.021237
#
#           INDICADOR_AJUIZADO  HA_OUTROS_DEBITOS  INSC_>1_ANO  \
# 1419707                    0                  1            1
# 7240218                    0                  1            1
# 8072359                    1                  1            1
# 6579675                    0                  1            0
# 12352983                   0                  1            1
#
#           VALOR_CONSOLIDADO  VALOR_FAIXA  COD_SIT_CADAST  COD_CNAE_PRINC  \
# 1419707        1.024026e-04     0.777778       -1.556471        0.275200
# 7240218        1.364299e-07     0.111111        0.490522        0.586070
# 8072359        2.608829e-05     0.666667       -1.556471        0.198774
# 6579675        2.460639e-07     0.111111        0.490522       -0.059852
# 12352983       2.765668e-07     0.111111        0.490522        0.295323
#
#           COD_NAT_JURID  COD_PORTE  ATIV_>10_ANOS  PARCELADO
# 1419707        0.023340   0.041484              1          0
# 7240218       -0.060573   0.041484              1          1
# 8072359        0.115958  -0.080524              1          0
# 6579675        0.147429   0.125105              0          1
# 12352983       0.023340   0.041484              1          1

# %%
# CHECANDO MAIS UMA VEZ SE HÁ DADOS NULOS / NAN (NOT A NUMBER)
df2.isna().sum()
# Out:
# TIPO_PESSOA           0
# COD_TIPO_SIT_INSC     0
# COD_SIT_INSC          0
# COD_RECEITA           0
# INDICADOR_AJUIZADO    0
# HA_OUTROS_DEBITOS     0
# INSC_>1_ANO           0
# VALOR_CONSOLIDADO     0
# VALOR_FAIXA           0
# COD_SIT_CADAST        0
# COD_CNAE_PRINC        0
# COD_NAT_JURID         0
# COD_PORTE             0
# ATIV_>10_ANOS         0
# PARCELADO             0
# dtype: int64

# %%
# SUBSTITUINDO DADOS NULOS / NAN POR ZERO
df2.fillna(value = 0, inplace = True)
df2.isna().sum()
# Out:
# TIPO_PESSOA           0
# COD_TIPO_SIT_INSC     0
# COD_SIT_INSC          0
# COD_RECEITA           0
# INDICADOR_AJUIZADO    0
# HA_OUTROS_DEBITOS     0
# INSC_>1_ANO           0
# VALOR_CONSOLIDADO     0
# VALOR_FAIXA           0
# COD_SIT_CADAST        0
# COD_CNAE_PRINC        0
# COD_NAT_JURID         0
# COD_PORTE             0
# ATIV_>10_ANOS         0
# PARCELADO             0
# dtype: int64

# %%
# %%time
# EXPORTANTO DATASET FINAL
df2.to_csv("07_dataset_final_com_dados_continuos.csv")
# Out:
# Wall time: 9.28 s

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 749647 entries, 1419707 to 10318597
# Data columns (total 15 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   TIPO_PESSOA         749647 non-null  int64
#  1   COD_TIPO_SIT_INSC   749647 non-null  float64
#  2   COD_SIT_INSC        749647 non-null  float64
#  3   COD_RECEITA         749647 non-null  float64
#  4   INDICADOR_AJUIZADO  749647 non-null  int64
#  5   HA_OUTROS_DEBITOS   749647 non-null  int64
#  6   INSC_>1_ANO         749647 non-null  int64
#  7   VALOR_CONSOLIDADO   749647 non-null  float64
#  8   VALOR_FAIXA         749647 non-null  float64
#  9   COD_SIT_CADAST      749647 non-null  float64
#  10  COD_CNAE_PRINC      749647 non-null  float64
#  11  COD_NAT_JURID       749647 non-null  float64
#  12  COD_PORTE           749647 non-null  float64
#  13  ATIV_>10_ANOS       749647 non-null  int64
#  14  PARCELADO           749647 non-null  int64
# dtypes: float64(9), int64(6)
# memory usage: 107.6 MB
